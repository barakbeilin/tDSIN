# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai import *
from fastai.vision import *
import torch
from torch import nn
from dsin.ae.data_manager.data_loader import (
    SideinformationImageImageList, ImageSiTuple)
from dsin.ae import config
from dsin.ae.si_ae import SideInformationAutoEncoder
from dsin.ae.si_net import SiNetChannelIn
from dsin.ae.loss_man import LossManager
from dsin.ae.distortions import Distortions, DistTypes
from dsin.ae.kitti_normalizer import ChangeImageStatsToKitti, ChangeState
from dsin.ae import config

# %%
config.H_target = 2* 0.3
# config.autoencoder_loss_distortion_to_minimize=DistTypes.MS_SSMIM
config.K_MS_SSIM=500
config.beta
# Out:
# 500

# %%
import time
import datetime
import logging

logger = logging.getLogger()

def setup_file_logger(log_file='out.log'):
    hdlr = logging.FileHandler(log_file)
    formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
    hdlr.setFormatter(formatter)
    logger.addHandler(hdlr) 
    logger.setLevel(logging.INFO)
    logger.info("start")

setup_file_logger()

# %%
class AverageMetric(Callback):
    "Wrap a `func` in a callback for metrics computation."
    def __init__(self, func,name):
        # If it's a partial, use func.func
        #         name = getattr(func,'func',func).__name__
        self.func, self.name = func, name

    def on_epoch_begin(self, **kwargs):
        "Set the inner value to 0."
        self.val, self.count = 0.,0

    def on_batch_end(self, last_output, last_target, **kwargs):
        "Update metric computation with `last_output` and `last_target`."
        if not is_listy(last_target): last_target=[last_target]
        self.count += last_target[0].size(0) # batch size
        
        if last_output[0] is None:
            X_OUTPUT = 1 # X_DEC
        else:
            X_OUTPUT = 0 # X_HAT_OUT
        val = self.func(last_output[X_OUTPUT], last_target[0])
        self.val += last_target[0].size(0) * val.detach().cpu()
        
    
    
    def on_epoch_end(self, last_metrics, **kwargs):
        "Set the final result in `last_metrics`."
        return add_metrics(last_metrics, self.val/self.count)
    
class ParameterMetricCallback(Callback):
    def __init__(self,loss_man):
        self.loss_man = loss_man
    
    def on_backward_begin(self,*args, **kwargs):
        self.pbar=kwargs["pbar"]
        if hasattr(self.loss_man,'soft_bit_entropy'):
            self.pbar.child.comment += f' soft_bit_entropy: {self.loss_man.soft_bit_entropy:.4f}'

class ParameterRunningAverageMetricCallback(Callback):
    def __init__(self,loss_man,alpha=0.1):
        self.loss_man = loss_man
        self.alpha = alpha
        self.val = None
    
    def on_backward_begin(self,*args, **kwargs):
        self.pbar=kwargs["pbar"]
        self.importance_map=kwargs["last_output"][3].detach()
#         import pdb
#         pdb.set_trace()
        if hasattr(self.loss_man,'soft_bit_entropy'):
            if self.val is None:
                self.val = self.loss_man.soft_bit_entropy.detach()
            else:
                self.val *= 1 - self.alpha
                self.val += self.alpha * self.loss_man.soft_bit_entropy.detach()
                
            self.pbar.child.comment += f' avg_bpp: {self.val / 2 :.4f} imp-mean-var {(torch.mean(self.importance_map),torch.var(self.importance_map))}'

# %%
class BitEntropy(Callback):
    "Wrap a `func` in a callback for metrics computation."
    def __init__(self,loss_man,alpha=0.1, logger=logger):
        # If it's a partial, use func.func
        #         name = getattr(func,'func',func).__name__
        self.loss_man = loss_man
        self.alpha = alpha
        self.logger = logger
        
    def on_epoch_begin(self, **kwargs):
        "Set the inner value to 0."
        self.val = 0.0
        self.iter = 0
        
    def on_batch_end(self, last_output, last_target, **kwargs):
        "Update metric computation with `last_output` and `last_target`."
      
        self.val *= 1 - self.alpha
        self.val += self.alpha * self.loss_man.soft_bit_entropy.detach()

        if self.iter % 500 == 0 :
            importance_map  = last_output[3].detach()
            msg = f"iter {self.iter}: bpp = {self.val / 2:.3f}, impmap- mean {torch.mean(importance_map):.4f} var {torch.var(importance_map):.4f} "
            msg += f" total loss{self.loss_man.total_loss:.1f}  l2reg_loss={self.loss_man.l2_reg_loss:.1f}"
            msg += f"autoencoder_loss_value={ self.loss_man.autoencoder_loss_value:.1f}"
            msg += f"si_loss={self.loss_man.si_net_loss_value}"
            self.logger.info(msg)
            print(msg)
        self.iter += 1

    def on_epoch_end(self, last_metrics, **kwargs):
        "Set the final result in `last_metrics`."
        return add_metrics(last_metrics, self.val)

# %%
config.use_si_flag = SiNetChannelIn.WithSideInformation
config.use_si_flag
# Out:
# <SiNetChannelIn.WithSideInformation: 6>

# %%
torch.__version__
# Out:
# '1.5.1'

# %%
si_autoencoder = SideInformationAutoEncoder(config.use_si_flag)
path = "../src/dsin/data"
pct= 1 #0.0005 #0.25

valid_image_list = SideinformationImageImageList.from_csv(
    path=path, csv_names=["KITTI_stereo_val.txt"],pct=pct)
train_image_list = SideinformationImageImageList.from_csv(
    path=path, csv_names=["KITTI_stereo_train.txt"],pct=pct)

image_lists = ItemLists(
    path=path, train=train_image_list, valid=valid_image_list)

# ll = image_lists.label_from_func(lambda x: x)

tfms =  get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1., max_lighting=None, max_warp=None, p_affine=0.0, p_lighting=0.0)
 #get_transforms(do_flip=True, max_rotate=0.0) # None #
batchsize = 1
# [flip_lr(p=0.5),[]]
data = (image_lists
        .label_from_func(lambda x: x)
        .transform(None, size=(336, 1224), resize_method=ResizeMethod.CROP, tfm_y=True)
        .databunch(bs=batchsize))
learn = Learner(data=data,
                     model=si_autoencoder,
                     opt_func=torch.optim.Adam,
                     loss_func=LossManager(SiNetChannelIn.WithSideInformation),
                     metrics=[AverageMetric(Distortions._calc_dist,"MS_SSIM")])

# learn.metrics.append(BitEntropy(loss_man=learn.loss_func))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /home/ubuntu/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# HBox(children=(FloatProgress(value=0.0, max=553507836.0), HTML(value='')))

# %%
learn.load('try2_200807MAE-l2reg-baseline-2')

model_fname = '200814MAE-l2reg-si'
for i in range(1,5):
    if i != 1 :
        learn.load(f'{model_fname}-{i - 1}',with_opt=True)
    
    config.si_loss_weight_alpha = 0.7
    learn.model.true_tuple_loss_false_just_out = True
    learn.model.use_side_infomation = SiNetChannelIn.WithSideInformation
    learn.loss_func.use_side_infomation = SiNetChannelIn.WithSideInformation
    learn.fit(1, lr=0.0001,wd=0,callbacks=[ParameterRunningAverageMetricCallback(learn.loss_func),BitEntropy(loss_man=learn.loss_func)])
    learn.save(f'{model_fname}-{i}')
    # !aws s3 cp ~/tDSIN/src/dsin/data/models/{model_fname}-{i}.pth  s3://dsin-us/models/
    # !aws s3 cp ~/tDSIN/tutorials/out.log s3://dsin-us/models/
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>MS_SSIM</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='1576', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.09% [96/1576 01:37<25:07 771.8293 avg_bpp: 0.4338 imp-mean-var (tensor(0.2752, device='cuda:0'), tensor(0.1995, device='cuda:0'))]
#     </div>
# iter 0: bpp = 0.043, impmap- mean 0.2562 var 0.1906  total loss696.2  l2reg_loss=40.4autoencoder_loss_value=11.1si_loss=62.22828674316406

# %%
learn.model.my_tuple[5]

# %%
learn.data.train_ds[1][0].img

# %%
learn.data.train_ds[1][0].si_img

# %%
learn.loss_func.soft_bit_entropy

# %%
config.si_loss_weight_alpha

# %%
learn.loss_func.autoencoder_loss_value

# %%
learn.load('try2_200807MAE-l2reg-baseline-2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (1576 items)
# x: SideinformationImageImageList
# ImageSiTuple [tensor([[[0.0763, 0.0793, 0.0785,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0766, 0.0775, 0.0755,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0518, 0.0547, 0.0576,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1078, 0.1076, 0.0978,  ..., 0.0774, 0.0630, 0.0559],
#          [0.1098, 0.1160, 0.1369,  ..., 0.0546, 0.0509, 0.0490],
#          [0.1007, 0.1306, 0.1882,  ..., 0.0350, 0.0380, 0.0410]],
#
#         [[0.0965, 0.0942, 0.0775,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0736, 0.0775, 0.0726,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0608, 0.0638, 0.0668,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1381, 0.1401, 0.1330,  ..., 0.0729, 0.0756, 0.0766],
#          [0.1501, 0.1529, 0.1425,  ..., 0.0548, 0.0557, 0.0558],
#          [0.1892, 0.2082, 0.2097,  ..., 0.0418, 0.0449, 0.0480]],
#
#         [[0.0676, 0.0347, 0.0333,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0677, 0.0645, 0.0606,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0669, 0.0885, 0.0960,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1794, 0.1932, 0.1904,  ..., 0.1168, 0.1197, 0.1188],
#          [0.1715, 0.1496, 0.1467,  ..., 0.1006, 0.1048, 0.0959],
#          [0.2411, 0.2644, 0.2887,  ..., 0.0887, 0.0928, 0.0932]]]), tensor([[[0.0866, 0.0857, 0.0909,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1137, 0.1107, 0.1078,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1178, 0.1198, 0.1188,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1303, 0.1213, 0.1057,  ..., 0.0451, 0.0490, 0.0491],
#          [0.1244, 0.1155, 0.1029,  ..., 0.0460, 0.0500, 0.0471],
#          [0.1216, 0.1105, 0.0990,  ..., 0.0469, 0.0509, 0.0501]],
#
#         [[0.0950, 0.0900, 0.0996,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1009, 0.1069, 0.1208,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1108, 0.1217, 0.1274,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1470, 0.1549, 0.1588,  ..., 0.0560, 0.0511, 0.0520],
#          [0.1549, 0.1599, 0.1637,  ..., 0.0607, 0.0628, 0.0599],
#          [0.1569, 0.1608, 0.1617,  ..., 0.0656, 0.0726, 0.0688]],
#
#         [[0.1020, 0.1146, 0.1118,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1077, 0.1215, 0.1226,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1245, 0.1324, 0.1362,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.2020, 0.1894, 0.1895,  ..., 0.0904, 0.0980, 0.1040],
#          [0.1911, 0.1784, 0.1816,  ..., 0.0647, 0.0762, 0.0960],
#          [0.2003, 0.2036, 0.2042,  ..., 0.0772, 0.0796, 0.0941]]])],ImageSiTuple [tensor([[[0.0688, 0.0757, 0.0753,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0752, 0.0772, 0.0793,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1228, 0.1224, 0.0866,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.0870, 0.0820, 0.0646,  ..., 0.0323, 0.0449, 0.0528],
#          [0.0852, 0.0772, 0.0637,  ..., 0.0342, 0.0410, 0.0499],
#          [0.0673, 0.0654, 0.0598,  ..., 0.0322, 0.0361, 0.0410]],
#
#         [[0.0775, 0.0636, 0.0607,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0774, 0.0724, 0.0732,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1014, 0.1084, 0.1079,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1059, 0.1077, 0.0995,  ..., 0.0411, 0.0363, 0.0264],
#          [0.1059, 0.1097, 0.1015,  ..., 0.0489, 0.0452, 0.0363],
#          [0.1059, 0.1158, 0.1105,  ..., 0.0477, 0.0500, 0.0453]],
#
#         [[0.0790, 0.0613, 0.0632,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0922, 0.0852, 0.0839,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1267, 0.1092, 0.1077,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.1166, 0.1119, 0.1147,  ..., 0.0406, 0.0432, 0.0441],
#          [0.1117, 0.1010, 0.1036,  ..., 0.0298, 0.0274, 0.0342],
#          [0.1189, 0.1102, 0.1136,  ..., 0.0488, 0.0417, 0.0434]]]), tensor([[[0.1032, 0.1004, 0.1195,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0941, 0.0934, 0.1095,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0971, 0.0954, 0.1053,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.0235, 0.0235, 0.0196,  ..., 0.0273, 0.0275, 0.0285],
#          [0.0324, 0.0294, 0.0226,  ..., 0.0274, 0.0245, 0.0275],
#          [0.0383, 0.0313, 0.0235,  ..., 0.0276, 0.0236, 0.0244]],
#
#         [[0.1101, 0.1162, 0.1427,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0961, 0.1093, 0.1411,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0983, 0.1071, 0.1208,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.0215, 0.0254, 0.0264,  ..., 0.0363, 0.0353, 0.0392],
#          [0.0265, 0.0275, 0.0274,  ..., 0.0323, 0.0294, 0.0303],
#          [0.0275, 0.0244, 0.0213,  ..., 0.0314, 0.0275, 0.0275]],
#
#         [[0.1364, 0.1648, 0.1712,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1295, 0.1602, 0.1755,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1176, 0.1453, 0.1618,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.0266, 0.0197, 0.0196,  ..., 0.0578, 0.0569, 0.0569],
#          [0.0176, 0.0098, 0.0125,  ..., 0.0489, 0.0461, 0.0460],
#          [0.0217, 0.0170, 0.0209,  ..., 0.0440, 0.0432, 0.0431]]])],ImageSiTuple [tensor([[[0.2881, 0.2879, 0.2774,  ..., 0.1887, 0.1862, 0.1937],
#          [0.2903, 0.2901, 0.2742,  ..., 0.1609, 0.1512, 0.1725],
#          [0.2754, 0.2744, 0.2723,  ..., 0.1439, 0.1391, 0.1675],
#          ...,
#          [0.1040, 0.1029, 0.0990,  ..., 0.5277, 0.5553, 0.5664],
#          [0.1020, 0.1019, 0.0980,  ..., 0.4792, 0.4719, 0.4786],
#          [0.1050, 0.1019, 0.0980,  ..., 0.4627, 0.4077, 0.3595]],
#
#         [[0.2911, 0.2972, 0.3001,  ..., 0.1787, 0.1717, 0.1725],
#          [0.2941, 0.2950, 0.2931,  ..., 0.1698, 0.1658, 0.1697],
#          [0.2931, 0.2969, 0.2911,  ..., 0.1578, 0.1559, 0.1598],
#          ...,
#          [0.1403, 0.1353, 0.1314,  ..., 0.4335, 0.4734, 0.5093],
#          [0.1313, 0.1304, 0.1294,  ..., 0.3413, 0.3899, 0.4319],
#          [0.1264, 0.1294, 0.1294,  ..., 0.3026, 0.3201, 0.3423]],
#
#         [[0.3273, 0.3469, 0.3469,  ..., 0.1228, 0.1284, 0.1294],
#          [0.3352, 0.3549, 0.3574,  ..., 0.1117, 0.1234, 0.1265],
#          [0.3402, 0.3559, 0.3660,  ..., 0.1058, 0.1175, 0.1176],
#          ...,
#          [0.1804, 0.1656, 0.1649,  ..., 0.3517, 0.3549, 0.4085],
#          [0.1774, 0.1775, 0.1775,  ..., 0.2690, 0.2594, 0.3043],
#          [0.1735, 0.1743, 0.1716,  ..., 0.2332, 0.2362, 0.2573]]]), tensor([[[0.2631, 0.2629, 0.2547,  ..., 0.1556, 0.1604, 0.1653],
#          [0.2510, 0.2510, 0.2550,  ..., 0.1655, 0.1743, 0.1813],
#          [0.2500, 0.2500, 0.2541,  ..., 0.1695, 0.1802, 0.1833],
#          ...,
#          [0.1049, 0.1059, 0.1059,  ..., 0.5175, 0.5205, 0.5206],
#          [0.1029, 0.1059, 0.1088,  ..., 0.5236, 0.5216, 0.5216],
#          [0.1020, 0.1059, 0.1098,  ..., 0.5317, 0.5247, 0.5246]],
#
#         [[0.2627, 0.2658, 0.2649,  ..., 0.1733, 0.1735, 0.1735],
#          [0.2627, 0.2617, 0.2579,  ..., 0.1764, 0.1755, 0.1765],
#          [0.2638, 0.2598, 0.2559,  ..., 0.1744, 0.1726, 0.1755],
#          ...,
#          [0.1274, 0.1284, 0.1275,  ..., 0.5122, 0.5290, 0.5350],
#          [0.1264, 0.1264, 0.1225,  ..., 0.5132, 0.5272, 0.5332],
#          [0.1255, 0.1255, 0.1246,  ..., 0.5136, 0.5164, 0.5053]],
#
#         [[0.3020, 0.2941, 0.2932,  ..., 0.1515, 0.1482, 0.1578],
#          [0.3010, 0.2960, 0.2941,  ..., 0.1506, 0.1471, 0.1617],
#          [0.2980, 0.3020, 0.3068,  ..., 0.1565, 0.1530, 0.1647],
#          ...,
#          [0.1618, 0.1608, 0.1609,  ..., 0.4734, 0.4821, 0.4980],
#          [0.1608, 0.1608, 0.1609,  ..., 0.4971, 0.4981, 0.5010],
#          [0.1578, 0.1548, 0.1582,  ..., 0.5018, 0.4990, 0.4989]]])],ImageSiTuple [tensor([[[0.2766, 0.2757, 0.2765,  ..., 0.9982, 0.9970, 0.9684],
#          [0.2715, 0.2686, 0.2715,  ..., 0.9942, 0.9999, 0.8541],
#          [0.2755, 0.2755, 0.2754,  ..., 0.8905, 0.8840, 0.7346],
#          ...,
#          [0.1059, 0.1058, 0.1020,  ..., 0.1815, 0.1721, 0.1536],
#          [0.1059, 0.1059, 0.1049,  ..., 0.1705, 0.1834, 0.1798],
#          [0.1059, 0.1089, 0.1089,  ..., 0.1628, 0.2036, 0.2414]],
#
#         [[0.2950, 0.2950, 0.2949,  ..., 1.0000, 0.9778, 0.9612],
#          [0.2961, 0.2971, 0.2970,  ..., 0.9664, 0.8520, 0.7682],
#          [0.2872, 0.2921, 0.2931,  ..., 0.7977, 0.6589, 0.5473],
#          ...,
#          [0.1294, 0.1295, 0.1332,  ..., 0.2233, 0.2056, 0.2228],
#          [0.1264, 0.1265, 0.1333,  ..., 0.2262, 0.2616, 0.3004],
#          [0.1225, 0.1316, 0.1364,  ..., 0.1998, 0.2318, 0.2603]],
#
#         [[0.3264, 0.3599, 0.3606,  ..., 1.0000, 0.9305, 0.8793],
#          [0.3304, 0.3569, 0.3615,  ..., 0.9266, 0.8455, 0.7991],
#          [0.3343, 0.3519, 0.3583,  ..., 0.6662, 0.5677, 0.5371],
#          ...,
#          [0.1804, 0.1734, 0.1736,  ..., 0.1845, 0.1884, 0.1674],
#          [0.1804, 0.1854, 0.1853,  ..., 0.1663, 0.1685, 0.1854],
#          [0.1774, 0.1791, 0.1762,  ..., 0.1309, 0.1404, 0.1520]]]), tensor([[[0.2570, 0.2571, 0.2599,  ..., 0.8581, 0.5438, 0.3985],
#          [0.2510, 0.2502, 0.2621,  ..., 0.7888, 0.5015, 0.4225],
#          [0.2520, 0.2492, 0.2582,  ..., 0.7391, 0.4745, 0.4455],
#          ...,
#          [0.1059, 0.1059, 0.1098,  ..., 0.5623, 0.5754, 0.5717],
#          [0.1059, 0.1059, 0.1039,  ..., 0.5577, 0.5665, 0.5657],
#          [0.1059, 0.1029, 0.1020,  ..., 0.5539, 0.5527, 0.5526]],
#
#         [[0.2697, 0.2667, 0.2707,  ..., 0.5658, 0.4312, 0.3107],
#          [0.2667, 0.2667, 0.2708,  ..., 0.5645, 0.4352, 0.3147],
#          [0.2677, 0.2667, 0.2698,  ..., 0.5615, 0.4264, 0.3176],
#          ...,
#          [0.1284, 0.1254, 0.1216,  ..., 0.5537, 0.5578, 0.5578],
#          [0.1324, 0.1314, 0.1274,  ..., 0.5560, 0.5539, 0.5549],
#          [0.1364, 0.1363, 0.1322,  ..., 0.5540, 0.5530, 0.5529]],
#
#         [[0.3059, 0.3029, 0.3028,  ..., 0.4506, 0.4702, 0.3798],
#          [0.3030, 0.3030, 0.3020,  ..., 0.4521, 0.4750, 0.3599],
#          [0.2941, 0.2931, 0.2893,  ..., 0.4726, 0.4879, 0.3390],
#          ...,
#          [0.1627, 0.1675, 0.1703,  ..., 0.5175, 0.5261, 0.5441],
#          [0.1706, 0.1784, 0.1762,  ..., 0.5687, 0.5631, 0.5570],
#          [0.1665, 0.1713, 0.1674,  ..., 0.5800, 0.5727, 0.5608]]])],ImageSiTuple [tensor([[[0.0579, 0.0619, 0.0685,  ..., 0.2482, 0.2486, 0.2534],
#          [0.0606, 0.0629, 0.0766,  ..., 0.2684, 0.2677, 0.2755],
#          [0.0825, 0.0797, 0.0865,  ..., 0.2732, 0.2677, 0.2744],
#          ...,
#          [0.1865, 0.1857, 0.2002,  ..., 0.1814, 0.1794, 0.1813],
#          [0.1745, 0.1746, 0.1822,  ..., 0.1744, 0.1803, 0.1813],
#          [0.1575, 0.1575, 0.1583,  ..., 0.1695, 0.1773, 0.1804]],
#
#         [[0.1128, 0.1129, 0.1151,  ..., 0.2020, 0.2155, 0.2148],
#          [0.1088, 0.1107, 0.1060,  ..., 0.2091, 0.2128, 0.2099],
#          [0.1008, 0.1117, 0.1076,  ..., 0.2044, 0.2069, 0.2090],
#          ...,
#          [0.2520, 0.2541, 0.2648,  ..., 0.2499, 0.2538, 0.2549],
#          [0.2480, 0.2522, 0.2667,  ..., 0.2539, 0.2549, 0.2579],
#          [0.2440, 0.2511, 0.2574,  ..., 0.2458, 0.2548, 0.2649]],
#
#         [[0.1454, 0.1354, 0.1354,  ..., 0.2482, 0.2385, 0.2305],
#          [0.1286, 0.1237, 0.1229,  ..., 0.2516, 0.2374, 0.2322],
#          [0.1127, 0.1078, 0.1042,  ..., 0.2416, 0.2441, 0.2481],
#          ...,
#          [0.3362, 0.3589, 0.3569,  ..., 0.3480, 0.3509, 0.3371],
#          [0.3343, 0.3480, 0.3476,  ..., 0.3548, 0.3559, 0.3501],
#          [0.3364, 0.3421, 0.3424,  ..., 0.3387, 0.3417, 0.3409]]]), tensor([[[0.4061, 0.3945, 0.5955,  ..., 0.6174, 0.4032, 0.3032],
#          [0.3197, 0.3342, 0.3236,  ..., 0.6167, 0.3985, 0.3372],
#          [0.3077, 0.3217, 0.2700,  ..., 0.5950, 0.3716, 0.3430],
#          ...,
#          [0.1853, 0.1844, 0.1922,  ..., 0.1799, 0.1880, 0.1852],
#          [0.1843, 0.1813, 0.1804,  ..., 0.1891, 0.1950, 0.1912],
#          [0.1843, 0.1803, 0.1766,  ..., 0.2044, 0.1992, 0.2012]],
#
#         [[0.3427, 0.2966, 0.3007,  ..., 0.4803, 0.3699, 0.2655],
#          [0.2709, 0.2701, 0.2904,  ..., 0.4903, 0.3820, 0.2736],
#          [0.2191, 0.2303, 0.2492,  ..., 0.5055, 0.3822, 0.2726],
#          ...,
#          [0.2383, 0.2451, 0.2419,  ..., 0.2574, 0.2451, 0.2254],
#          [0.2323, 0.2342, 0.2301,  ..., 0.2682, 0.2688, 0.2482],
#          [0.2344, 0.2375, 0.2426,  ..., 0.2671, 0.2714, 0.2579]],
#
#         [[0.1765, 0.1646, 0.1609,  ..., 0.6458, 0.6740, 0.5339],
#          [0.1631, 0.1532, 0.1503,  ..., 0.6488, 0.6835, 0.5069],
#          [0.1206, 0.1156, 0.1138,  ..., 0.6839, 0.7112, 0.4900],
#          ...,
#          [0.3275, 0.3198, 0.3196,  ..., 0.3753, 0.3561, 0.3352],
#          [0.3196, 0.3049, 0.3075,  ..., 0.3851, 0.3660, 0.3373],
#          [0.3327, 0.3321, 0.3293,  ..., 0.3578, 0.3566, 0.3433]]])]
# y: ImageList
# Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224)
# Path: ../src/dsin/data;
#
# Valid: LabelList (790 items)
# x: SideinformationImageImageList
# ImageSiTuple [tensor([[[0.1292, 0.1241, 0.0657,  ..., 0.1980, 0.2005, 0.1973],
#          [0.0302, 0.0362, 0.0402,  ..., 0.2520, 0.2615, 0.2284],
#          [0.0520, 0.0519, 0.0430,  ..., 0.2520, 0.2461, 0.2082],
#          ...,
#          [0.3570, 0.3570, 0.3551,  ..., 0.0644, 0.0595, 0.0545],
#          [0.3529, 0.3529, 0.3520,  ..., 0.1793, 0.1932, 0.1895],
#          [0.3439, 0.3469, 0.3499,  ..., 0.2633, 0.3207, 0.3781]],
#
#         [[0.0944, 0.1136, 0.1407,  ..., 0.2734, 0.2730, 0.2694],
#          [0.0804, 0.0617, 0.0621,  ..., 0.3026, 0.2820, 0.2650],
#          [0.0695, 0.0684, 0.0585,  ..., 0.2575, 0.2344, 0.2205],
#          ...,
#          [0.3589, 0.3441, 0.3403,  ..., 0.0778, 0.1004, 0.1289],
#          [0.3539, 0.3411, 0.3374,  ..., 0.1838, 0.2482, 0.2993],
#          [0.3560, 0.3472, 0.3465,  ..., 0.4023, 0.4177, 0.4305]],
#
#         [[0.0588, 0.0957, 0.0996,  ..., 0.2556, 0.2558, 0.2558],
#          [0.0588, 0.0679, 0.0724,  ..., 0.2499, 0.2361, 0.2330],
#          [0.0558, 0.0460, 0.0431,  ..., 0.1766, 0.1599, 0.1509],
#          ...,
#          [0.3352, 0.3342, 0.3343,  ..., 0.1519, 0.1390, 0.1667],
#          [0.3402, 0.3402, 0.3399,  ..., 0.1530, 0.1384, 0.2326],
#          [0.3412, 0.3412, 0.3412,  ..., 0.3867, 0.3720, 0.3578]]]), tensor([[[0.0323, 0.0322, 0.0301,  ..., 0.2110, 0.2192, 0.2160],
#          [0.0353, 0.0354, 0.0393,  ..., 0.1967, 0.2346, 0.2460],
#          [0.0343, 0.0343, 0.0385,  ..., 0.1883, 0.2293, 0.2337],
#          ...,
#          [0.4478, 0.4296, 0.3811,  ..., 0.3156, 0.3155, 0.3145],
#          [0.3897, 0.4143, 0.4631,  ..., 0.3218, 0.3186, 0.3186],
#          [0.3384, 0.4184, 0.5176,  ..., 0.3248, 0.3177, 0.3176]],
#
#         [[0.0353, 0.0362, 0.0362,  ..., 0.2980, 0.3614, 0.4287],
#          [0.0353, 0.0392, 0.0403,  ..., 0.2606, 0.3193, 0.3986],
#          [0.0343, 0.0383, 0.0422,  ..., 0.2121, 0.2473, 0.3121],
#          ...,
#          [0.4058, 0.4049, 0.4076,  ..., 0.3052, 0.3010, 0.2990],
#          [0.4019, 0.3960, 0.3974,  ..., 0.3150, 0.3080, 0.3040],
#          [0.3759, 0.3806, 0.4142,  ..., 0.3299, 0.3250, 0.3119]],
#
#         [[0.0392, 0.0353, 0.0353,  ..., 0.2022, 0.1777, 0.2857],
#          [0.0392, 0.0372, 0.0372,  ..., 0.1797, 0.1681, 0.2830],
#          [0.0392, 0.0432, 0.0441,  ..., 0.1308, 0.1264, 0.1980],
#          ...,
#          [0.3903, 0.3705, 0.3724,  ..., 0.3070, 0.3010, 0.2862],
#          [0.3823, 0.3667, 0.3739,  ..., 0.2932, 0.2989, 0.3080],
#          [0.3925, 0.4070, 0.4092,  ..., 0.3114, 0.3101, 0.3167]]])],ImageSiTuple [tensor([[[0.0501, 0.0574, 0.0804,  ..., 0.9119, 0.9239, 0.9080],
#          [0.0652, 0.0657, 0.0914,  ..., 0.9029, 0.9040, 0.9020],
#          [0.1256, 0.1198, 0.1098,  ..., 0.9039, 0.9051, 0.9040],
#          ...,
#          [0.4024, 0.3993, 0.4068,  ..., 0.1923, 0.1941, 0.1981],
#          [0.3882, 0.3862, 0.3867,  ..., 0.1852, 0.1804, 0.1783],
#          [0.3731, 0.3660, 0.3529,  ..., 0.1842, 0.1677, 0.1544]],
#
#         [[0.0751, 0.0735, 0.0908,  ..., 0.9997, 1.0000, 1.0000],
#          [0.0998, 0.0977, 0.1031,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1284, 0.1512, 0.1561,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.3903, 0.3903, 0.3778,  ..., 0.2579, 0.2589, 0.2560],
#          [0.3467, 0.3598, 0.3727,  ..., 0.2375, 0.2371, 0.2421],
#          [0.3273, 0.3473, 0.3759,  ..., 0.2319, 0.2165, 0.2181]],
#
#         [[0.0690, 0.0765, 0.0722,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1514, 0.1259, 0.1181,  ..., 1.0000, 1.0000, 1.0000],
#          [0.2136, 0.1824, 0.1755,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.3933, 0.3786, 0.3762,  ..., 0.1432, 0.1463, 0.1501],
#          [0.3734, 0.3489, 0.3519,  ..., 0.1245, 0.1225, 0.1273],
#          [0.3686, 0.3624, 0.3703,  ..., 0.1218, 0.1177, 0.1246]]]), tensor([[[0.0833, 0.0833, 0.0842,  ..., 0.8876, 0.8744, 0.8700],
#          [0.0863, 0.0844, 0.0893,  ..., 0.8774, 0.8880, 0.8960],
#          [0.0994, 0.0936, 0.0954,  ..., 0.8753, 0.8889, 0.8939],
#          ...,
#          [0.4775, 0.4763, 0.4597,  ..., 0.1943, 0.1892, 0.1930],
#          [0.4538, 0.4598, 0.4679,  ..., 0.1904, 0.1863, 0.1901],
#          [0.4320, 0.4492, 0.4737,  ..., 0.1854, 0.1784, 0.1792]],
#
#         [[0.1086, 0.1057, 0.0959,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1186, 0.1038, 0.0900,  ..., 1.0000, 1.0000, 1.0000],
#          [0.1216, 0.1020, 0.0984,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.5071, 0.4846, 0.4813,  ..., 0.2650, 0.2539, 0.2558],
#          [0.4714, 0.4747, 0.4855,  ..., 0.2740, 0.2561, 0.2559],
#          [0.4658, 0.4808, 0.4956,  ..., 0.2596, 0.2460, 0.2338]],
#
#         [[0.0745, 0.0736, 0.0707,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0774, 0.0725, 0.0706,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0812, 0.0743, 0.0686,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.5010, 0.5136, 0.5136,  ..., 0.1383, 0.1411, 0.1441],
#          [0.5049, 0.5206, 0.5177,  ..., 0.1315, 0.1410, 0.1510],
#          [0.5119, 0.5216, 0.5211,  ..., 0.1386, 0.1411, 0.1469]]])],ImageSiTuple [tensor([[[0.0305, 0.0304, 0.0266,  ..., 0.1751, 0.1759, 0.1629],
#          [0.0284, 0.0283, 0.0245,  ..., 0.1694, 0.1609, 0.2018],
#          [0.0314, 0.0313, 0.0283,  ..., 0.1551, 0.1448, 0.1913],
#          ...,
#          [0.0835, 0.0855, 0.0942,  ..., 0.2892, 0.2853, 0.2803],
#          [0.0784, 0.0794, 0.0821,  ..., 0.2544, 0.2975, 0.3209],
#          [0.0724, 0.0693, 0.0633,  ..., 0.2162, 0.2888, 0.3635]],
#
#         [[0.0392, 0.0392, 0.0383,  ..., 0.2404, 0.2371, 0.2217],
#          [0.0373, 0.0382, 0.0354,  ..., 0.2327, 0.2722, 0.2817],
#          [0.0314, 0.0363, 0.0372,  ..., 0.1821, 0.2224, 0.2159],
#          ...,
#          [0.1059, 0.1098, 0.1119,  ..., 0.2628, 0.2791, 0.2824],
#          [0.1000, 0.1010, 0.1039,  ..., 0.2800, 0.3028, 0.3061],
#          [0.0920, 0.0920, 0.0896,  ..., 0.3123, 0.3336, 0.3318]],
#
#         [[0.0305, 0.0344, 0.0371,  ..., 0.1006, 0.1227, 0.1448],
#          [0.0275, 0.0294, 0.0284,  ..., 0.1039, 0.1293, 0.1425],
#          [0.0285, 0.0255, 0.0227,  ..., 0.0841, 0.0930, 0.0970],
#          ...,
#          [0.1069, 0.1060, 0.1031,  ..., 0.1919, 0.1912, 0.2020],
#          [0.0940, 0.0842, 0.0863,  ..., 0.1846, 0.1921, 0.1970],
#          [0.0842, 0.0724, 0.0734,  ..., 0.2016, 0.2131, 0.2021]]]), tensor([[[0.0305, 0.0305, 0.0314,  ..., 0.1627, 0.1537, 0.1514],
#          [0.0275, 0.0275, 0.0304,  ..., 0.1686, 0.1696, 0.1725],
#          [0.0275, 0.0275, 0.0276,  ..., 0.1746, 0.1825, 0.1857],
#          ...,
#          [0.0960, 0.0960, 0.0941,  ..., 0.2910, 0.2514, 0.2596],
#          [0.0832, 0.0803, 0.0823,  ..., 0.2933, 0.2584, 0.2667],
#          [0.0724, 0.0715, 0.0754,  ..., 0.2847, 0.2651, 0.2697]],
#
#         [[0.0371, 0.0362, 0.0332,  ..., 0.1948, 0.1958, 0.1928],
#          [0.0441, 0.0402, 0.0392,  ..., 0.2067, 0.2088, 0.2098],
#          [0.0460, 0.0431, 0.0392,  ..., 0.2187, 0.2139, 0.2157],
#          ...,
#          [0.1127, 0.1137, 0.1107,  ..., 0.3087, 0.2836, 0.2775],
#          [0.1048, 0.1019, 0.1007,  ..., 0.3188, 0.3130, 0.2982],
#          [0.0929, 0.0889, 0.0858,  ..., 0.3486, 0.3428, 0.3330]],
#
#         [[0.0440, 0.0361, 0.0323,  ..., 0.1270, 0.1294, 0.1255],
#          [0.0442, 0.0382, 0.0343,  ..., 0.1330, 0.1304, 0.1284],
#          [0.0353, 0.0342, 0.0314,  ..., 0.1331, 0.1323, 0.1373],
#          ...,
#          [0.1354, 0.1334, 0.1322,  ..., 0.2185, 0.1916, 0.1509],
#          [0.1333, 0.1294, 0.1290,  ..., 0.2038, 0.1923, 0.1648],
#          [0.1092, 0.1022, 0.0993,  ..., 0.2210, 0.2075, 0.1747]]])],ImageSiTuple [tensor([[[0.7226, 0.6428, 0.2876,  ..., 0.1225, 0.1254, 0.1113],
#          [0.9844, 0.9866, 0.4771,  ..., 0.1574, 0.1693, 0.1294],
#          [0.9796, 0.9947, 0.6261,  ..., 0.1576, 0.1551, 0.1102],
#          ...,
#          [0.1866, 0.1863, 0.1774,  ..., 0.5541, 0.5355, 0.5284],
#          [0.1646, 0.1566, 0.1486,  ..., 0.5512, 0.5521, 0.5502],
#          [0.1185, 0.1158, 0.1170,  ..., 0.5493, 0.5686, 0.5870]],
#
#         [[0.9276, 0.8576, 0.6141,  ..., 0.1667, 0.1701, 0.1330],
#          [0.9990, 0.9992, 0.9360,  ..., 0.1788, 0.1759, 0.1394],
#          [0.9971, 1.0000, 0.9947,  ..., 0.1398, 0.1254, 0.1084],
#          ...,
#          [0.1718, 0.1639, 0.1570,  ..., 0.5400, 0.5518, 0.5597],
#          [0.1440, 0.1349, 0.1211,  ..., 0.5498, 0.5675, 0.5795],
#          [0.1131, 0.1144, 0.1168,  ..., 0.5435, 0.5662, 0.5783]],
#
#         [[0.9991, 0.9955, 0.9915,  ..., 0.1238, 0.1385, 0.1614],
#          [0.9970, 0.9854, 0.9926,  ..., 0.1108, 0.1364, 0.1487],
#          [0.9990, 0.9658, 0.9674,  ..., 0.0862, 0.0697, 0.0607],
#          ...,
#          [0.1442, 0.1266, 0.1237,  ..., 0.5188, 0.5158, 0.5304],
#          [0.1056, 0.0890, 0.0911,  ..., 0.5239, 0.5168, 0.5324],
#          [0.1032, 0.0936, 0.0979,  ..., 0.4924, 0.4875, 0.5092]]]), tensor([[[0.1210, 0.1273, 0.1257,  ..., 0.0759, 0.1010, 0.1149],
#          [0.1021, 0.0892, 0.1441,  ..., 0.0977, 0.1298, 0.1480],
#          [0.1397, 0.1159, 0.1769,  ..., 0.1004, 0.1305, 0.1387],
#          ...,
#          [0.3611, 0.3000, 0.1816,  ..., 0.5141, 0.5250, 0.5183],
#          [0.2479, 0.2054, 0.1656,  ..., 0.4859, 0.4956, 0.4998],
#          [0.1315, 0.1366, 0.1520,  ..., 0.4451, 0.4253, 0.4298]],
#
#         [[0.2197, 0.1681, 0.1696,  ..., 0.1118, 0.1247, 0.1391],
#          [0.1067, 0.1120, 0.1270,  ..., 0.1347, 0.1488, 0.1422],
#          [0.1246, 0.1340, 0.1945,  ..., 0.1317, 0.1398, 0.1273],
#          ...,
#          [0.3059, 0.3793, 0.3634,  ..., 0.5127, 0.5137, 0.5059],
#          [0.2406, 0.2512, 0.1975,  ..., 0.4963, 0.4872, 0.4881],
#          [0.2256, 0.2513, 0.2751,  ..., 0.4721, 0.4635, 0.4673]],
#
#         [[0.2042, 0.2202, 0.2414,  ..., 0.1037, 0.1068, 0.0980],
#          [0.2103, 0.2288, 0.2205,  ..., 0.1119, 0.1089, 0.0952],
#          [0.2626, 0.4188, 0.4878,  ..., 0.1110, 0.1070, 0.0863],
#          ...,
#          [0.3222, 0.3701, 0.3449,  ..., 0.4685, 0.4647, 0.4648],
#          [0.1629, 0.1708, 0.1754,  ..., 0.4922, 0.4787, 0.4568],
#          [0.3618, 0.4569, 0.4320,  ..., 0.4856, 0.4765, 0.4579]]])],ImageSiTuple [tensor([[[0.2567, 0.2529, 0.2011,  ..., 0.2631, 0.2627, 0.2636],
#          [0.2580, 0.2591, 0.2078,  ..., 0.2631, 0.2627, 0.2667],
#          [0.2401, 0.2464, 0.2108,  ..., 0.2610, 0.2617, 0.2657],
#          ...,
#          [0.1283, 0.1262, 0.1156,  ..., 0.1981, 0.1875, 0.1825],
#          [0.1304, 0.1263, 0.1167,  ..., 0.2050, 0.1963, 0.1913],
#          [0.1234, 0.1224, 0.1176,  ..., 0.2168, 0.2151, 0.2142]],
#
#         [[0.2784, 0.2595, 0.2455,  ..., 0.3167, 0.3099, 0.3068],
#          [0.2784, 0.2634, 0.2425,  ..., 0.3119, 0.3079, 0.3088],
#          [0.2764, 0.2653, 0.2413,  ..., 0.3061, 0.3020, 0.3069],
#          ...,
#          [0.1490, 0.1413, 0.1442,  ..., 0.2640, 0.2657, 0.2726],
#          [0.1431, 0.1403, 0.1442,  ..., 0.2935, 0.2807, 0.2736],
#          [0.1442, 0.1473, 0.1512,  ..., 0.2836, 0.2922, 0.2926]],
#
#         [[0.2932, 0.2471, 0.2503,  ..., 0.3783, 0.3842, 0.3873],
#          [0.2883, 0.2480, 0.2486,  ..., 0.3835, 0.3824, 0.3824],
#          [0.2844, 0.2508, 0.2410,  ..., 0.3805, 0.3765, 0.3765],
#          ...,
#          [0.1951, 0.2078, 0.2077,  ..., 0.3581, 0.3508, 0.3715],
#          [0.1961, 0.2048, 0.2021,  ..., 0.3900, 0.3875, 0.3874],
#          [0.2051, 0.2160, 0.2151,  ..., 0.3374, 0.3536, 0.3620]]]), tensor([[[0.1481, 0.1518, 0.1377,  ..., 0.2741, 0.2492, 0.2377],
#          [0.1451, 0.1480, 0.1409,  ..., 0.2570, 0.2559, 0.2588],
#          [0.1461, 0.1460, 0.1420,  ..., 0.2529, 0.2597, 0.2598],
#          ...,
#          [0.1274, 0.1244, 0.1176,  ..., 0.0959, 0.0979, 0.0979],
#          [0.1235, 0.1225, 0.1206,  ..., 0.0920, 0.0989, 0.0990],
#          [0.1216, 0.1216, 0.1216,  ..., 0.0871, 0.0919, 0.0920]],
#
#         [[0.1538, 0.1607, 0.1566,  ..., 0.3039, 0.3041, 0.3020],
#          [0.1588, 0.1617, 0.1575,  ..., 0.2981, 0.2980, 0.3020],
#          [0.1647, 0.1657, 0.1616,  ..., 0.2991, 0.2981, 0.3020],
#          ...,
#          [0.1373, 0.1373, 0.1404,  ..., 0.1031, 0.1030, 0.1001],
#          [0.1373, 0.1403, 0.1442,  ..., 0.0961, 0.0960, 0.0951],
#          [0.1373, 0.1382, 0.1391,  ..., 0.0973, 0.0971, 0.0941]],
#
#         [[0.1451, 0.1560, 0.1569,  ..., 0.3436, 0.3412, 0.3460],
#          [0.1508, 0.1568, 0.1588,  ..., 0.3377, 0.3402, 0.3462],
#          [0.1696, 0.1696, 0.1657,  ..., 0.3364, 0.3362, 0.3373],
#          ...,
#          [0.1816, 0.1806, 0.1767,  ..., 0.1070, 0.1205, 0.1413],
#          [0.1637, 0.1666, 0.1657,  ..., 0.1029, 0.1087, 0.1195],
#          [0.1638, 0.1617, 0.1652,  ..., 0.1110, 0.1119, 0.1137]]])]
# y: ImageList
# Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224),Image (3, 336, 1224)
# Path: ../src/dsin/data;
#
# Test: None, model=SideInformationAutoEncoder(
#   (enc): Encoder(
#     (pre_res_model): Sequential(
#       (0): ChangeImageStatsToKitti()
#       (1): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): Conv2d(3, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): Conv2d(64, 128, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (res_model): Sequential(
#       (0): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (1): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (2): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (3): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (4): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (5): ResBlock(
#         (model): Sequential(
#           (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#         )
#       )
#     )
#     (post_sum_model): Conv2d(128, 33, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   )
#   (dec): Decoder(
#     (pre_uberblock_model): Conv2dReluBatch2d(
#       (model): Sequential(
#         (0): ConvTranspose2d(32, 128, kernel_size=[3, 3], stride=[2, 2], padding=[1, 1], output_padding=[1, 1])
#         (1): ReLU()
#         (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (pre_sum_model): Sequential(
#       (0): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (1): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (2): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (3): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (4): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (5): ResBlock(
#         (model): Sequential(
#           (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#         )
#       )
#     )
#     (post_sum_model): Sequential(
#       (0): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): ConvTranspose2d(128, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#           (1): ReLU()
#           (2): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): ConvTranspose2d(64, 3, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#       (2): ChangeImageStatsToKitti()
#     )
#   )
#   (importance_map_layer): ImportanceMapMult()
#   (quantizer): Quantizer(sigma=0.1)
#   (prob_classif): ProbClassifier(
#     (premodel): ConstantPad3d(padding=(4, 4, 4, 4, 4, 0, 0, 0), value=0)
#     (model): Sequential(
#       (0): MaskedConv3d(
#         (conv): Conv3d(1, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#       )
#       (1): ReLU()
#       (2): MaskedResblock(
#         (model): Sequential(
#           (0): MaskedConv3d(
#             (conv): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#           )
#           (1): ReLU()
#           (2): MaskedConv3d(
#             (conv): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#           )
#         )
#       )
#       (3): MaskedConv3d(
#         (conv): Conv3d(24, 6, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#       )
#       (4): ReLU()
#     )
#   )
#   (si_net): SiNet(
#     (model): Sequential(
#       (0): Conv2d(6, 32, kernel_size=[3, 3], stride=(1, 1), padding=[1, 1], padding_mode=replicate)
#       (1): LeakyReLU(negative_slope=0.2)
#       (2): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[2, 2], dilation=(2, 2), padding_mode=replicate)
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[4, 4], dilation=(4, 4), padding_mode=replicate)
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[8, 8], dilation=(8, 8), padding_mode=replicate)
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[16, 16], dilation=(16, 16), padding_mode=replicate)
#       (9): LeakyReLU(negative_slope=0.2)
#       (10): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[32, 32], dilation=(32, 32), padding_mode=replicate)
#       (11): LeakyReLU(negative_slope=0.2)
#       (12): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[64, 64], dilation=(64, 64), padding_mode=replicate)
#       (13): LeakyReLU(negative_slope=0.2)
#       (14): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[128, 128], dilation=(128, 128), padding_mode=replicate)
#       (15): LeakyReLU(negative_slope=0.2)
#       (16): Conv2d(32, 3, kernel_size=[1, 1], stride=(1, 1))
#       (17): ChangeImageStatsToKitti()
#     )
#   )
#   (si_finder): SiFinder()
#   (noramlize): ChangeImageStatsToKitti()
#   (denoramlize): ChangeImageStatsToKitti()
# ), opt_func=<class 'torch.optim.adam.Adam'>, loss_func=LossManager(
#   (bit_cost_loss): CrossEntropyLoss()
#   (si_net_loss): L1Loss()
#   (feat_loss): FeatureLoss(
#     (m_feat): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): ReLU(inplace=True)
#       (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): ReLU(inplace=True)
#       (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (16): ReLU(inplace=True)
#       (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): ReLU(inplace=True)
#       (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (26): ReLU(inplace=True)
#       (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (29): ReLU(inplace=True)
#       (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (32): ReLU(inplace=True)
#       (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (36): ReLU(inplace=True)
#       (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): ReLU(inplace=True)
#       (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (42): ReLU(inplace=True)
#       (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
# ), metrics=[AverageMetric
# func: <function Distortions._calc_dist at 0x7f140a405e60>
# name: MS_SSIM], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('../src/dsin/data'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): ChangeImageStatsToKitti()
#   (1): Conv2d(3, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (2): ReLU()
#   (3): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Conv2d(64, 128, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (5): ReLU()
#   (6): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (8): ReLU()
#   (9): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (11): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (12): ReLU()
#   (13): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (15): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (16): ReLU()
#   (17): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (19): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (20): ReLU()
#   (21): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (23): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (24): ReLU()
#   (25): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (27): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (28): ReLU()
#   (29): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (30): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (31): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (32): ReLU()
#   (33): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (35): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (36): ReLU()
#   (37): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (38): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (39): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (40): ReLU()
#   (41): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (42): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (43): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (44): ReLU()
#   (45): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (47): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (48): ReLU()
#   (49): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (50): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (51): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (52): ReLU()
#   (53): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (54): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (55): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (56): ReLU()
#   (57): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (59): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (60): ReLU()
#   (61): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (62): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (63): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (64): ReLU()
#   (65): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (66): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (67): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (68): ReLU()
#   (69): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (71): Conv2d(128, 33, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (72): ConvTranspose2d(32, 128, kernel_size=[3, 3], stride=[2, 2], padding=[1, 1], output_padding=[1, 1])
#   (73): ReLU()
#   (74): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (75): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (76): ReLU()
#   (77): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (78): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (79): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (80): ReLU()
#   (81): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (83): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (84): ReLU()
#   (85): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (86): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (87): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (88): ReLU()
#   (89): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (90): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (91): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (92): ReLU()
#   (93): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (94): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (95): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (96): ReLU()
#   (97): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (98): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (99): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (100): ReLU()
#   (101): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (102): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (103): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (104): ReLU()
#   (105): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (106): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (107): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (108): ReLU()
#   (109): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (111): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (112): ReLU()
#   (113): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (114): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (115): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (116): ReLU()
#   (117): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (118): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (119): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (120): ReLU()
#   (121): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (122): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (123): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (124): ReLU()
#   (125): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (126): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (127): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (128): ReLU()
#   (129): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (130): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (131): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (132): ReLU()
#   (133): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (134): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (135): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (136): ReLU()
#   (137): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (138): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (139): ConvTranspose2d(128, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#   (140): ReLU()
#   (141): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (142): ConvTranspose2d(64, 3, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#   (143): ChangeImageStatsToKitti()
#   (144): ImportanceMapMult()
#   (145): Quantizer(sigma=0.1)
#   (146): ConstantPad3d(padding=(4, 4, 4, 4, 4, 0, 0, 0), value=0)
#   (147): Conv3d(1, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (148): ReLU()
#   (149): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (150): ReLU()
#   (151): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (152): Conv3d(24, 6, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (153): ReLU()
#   (154): Conv2d(6, 32, kernel_size=[3, 3], stride=(1, 1), padding=[1, 1], padding_mode=replicate)
#   (155): LeakyReLU(negative_slope=0.2)
#   (156): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[2, 2], dilation=(2, 2), padding_mode=replicate)
#   (157): LeakyReLU(negative_slope=0.2)
#   (158): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[4, 4], dilation=(4, 4), padding_mode=replicate)
#   (159): LeakyReLU(negative_slope=0.2)
#   (160): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[8, 8], dilation=(8, 8), padding_mode=replicate)
#   (161): LeakyReLU(negative_slope=0.2)
#   (162): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[16, 16], dilation=(16, 16), padding_mode=replicate)
#   (163): LeakyReLU(negative_slope=0.2)
#   (164): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[32, 32], dilation=(32, 32), padding_mode=replicate)
#   (165): LeakyReLU(negative_slope=0.2)
#   (166): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[64, 64], dilation=(64, 64), padding_mode=replicate)
#   (167): LeakyReLU(negative_slope=0.2)
#   (168): Conv2d(32, 32, kernel_size=[3, 3], stride=(1, 1), padding=[128, 128], dilation=(128, 128), padding_mode=replicate)
#   (169): LeakyReLU(negative_slope=0.2)
#   (170): Conv2d(32, 3, kernel_size=[1, 1], stride=(1, 1))
#   (171): ChangeImageStatsToKitti()
#   (172): SiFinder()
#   (173): ChangeImageStatsToKitti()
#   (174): ChangeImageStatsToKitti()
# )], add_time=True, silent=False)

# %%
mt = learn.model.my_tuple[-2].squeeze_().detach()
mx, mn =torch.max(mt), torch.min(mt)
diff = mx-mn
show_image(Image((mt - mn)/(diff)),figsize=(30,30))
# # print(mn)

# %%
# # show_image(Image(learn.model.my_tuple[0][:,:50,:50]/255))
# # Image(learn.model.my_tuple[2].squeeze_().detach()/255.0)
mt = learn.model.my_tuple[2].squeeze_().detach()
mx, mn =torch.max(mt), torch.min(mt)
diff = mx-mn
show_image(Image((mt - mn)/(diff)),figsize=(30,30))
# # print(mn)

# torch.min(learn.model.my_tuple[2].squeeze_().detach())

# %%
aaa = (mt - mn)/(diff)

flip_lr(Image(aaa.cpu()))

# %%
# learn.model.true_tuple_loss_false_just_out = False

# learn.show_results(figsize=(30,30))

# %%
learn.model.my_tuple[-2].data
