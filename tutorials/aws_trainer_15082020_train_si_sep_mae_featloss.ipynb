# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai import *
from fastai.vision import *
from fastai.callbacks import *

import torch
from torch import nn
from dsin.ae.data_manager.data_loader import (
    SideinformationImageImageList, ImageSiTuple)
from dsin.ae import config
from dsin.ae.base_ae import BaseAutoEncoder
from dsin.ae.si_autoenc import SideInformationAutoEncoder

from dsin.ae.si_net import SiNetChannelIn
from dsin.ae.loss_man import LossManager
from dsin.ae.distortions import Distortions, DistTypes
from dsin.ae.kitti_normalizer import ChangeImageStatsToKitti, ChangeState
from dsin.ae import config

# %%
config.H_target = 2* 0.3
# config.autoencoder_loss_distortion_to_minimize=DistTypes.MS_SSMIM
config.K_MS_SSIM=500
config.beta
# Out:
# 500

# %%
import time
import datetime
import logging

logger = logging.getLogger()

def setup_file_logger(log_file='out.log'):
    hdlr = logging.FileHandler(log_file)
    formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
    hdlr.setFormatter(formatter)
    logger.addHandler(hdlr) 
    logger.setLevel(logging.INFO)
    logger.info("start")

setup_file_logger()

# %%
class AverageMetric(Callback):
    "Wrap a `func` in a callback for metrics computation."
    def __init__(self, func,name):
        # If it's a partial, use func.func
        #         name = getattr(func,'func',func).__name__
        self.func, self.name = func, name

    def on_epoch_begin(self, **kwargs):
        "Set the inner value to 0."
        self.val, self.count = 0.,0

    def on_batch_end(self, last_output, last_target, **kwargs):
        "Update metric computation with `last_output` and `last_target`."
        if not is_listy(last_target): last_target=[last_target]
        self.count += last_target[0].size(0) # batch size
        
        if last_output[0] is None:
            X_OUTPUT = 1 # X_DEC
        else:
            X_OUTPUT = 0 # X_HAT_OUT
        val = self.func(last_output[X_OUTPUT], last_target[0])
        self.val += last_target[0].size(0) * val.detach().cpu()
        
    
    
    def on_epoch_end(self, last_metrics, **kwargs):
        "Set the final result in `last_metrics`."
        return add_metrics(last_metrics, self.val/self.count)
    
class ParameterMetricCallback(Callback):
    def __init__(self,loss_man):
        self.loss_man = loss_man
    
    def on_backward_begin(self,*args, **kwargs):
        self.pbar=kwargs["pbar"]
        if hasattr(self.loss_man,'soft_bit_entropy'):
            self.pbar.child.comment += f' soft_bit_entropy: {self.loss_man.soft_bit_entropy:.4f}'

class ParameterRunningAverageMetricCallback(Callback):
    def __init__(self,loss_man,alpha=0.1):
        self.loss_man = loss_man
        self.alpha = alpha
        self.val = None
    
    def on_backward_begin(self,*args, **kwargs):
        self.pbar=kwargs["pbar"]
        self.importance_map=kwargs["last_output"][3].detach()
#         import pdb
#         pdb.set_trace()
        if hasattr(self.loss_man,'soft_bit_entropy'):
            if self.val is None:
                self.val = self.loss_man.soft_bit_entropy.detach()
            else:
                self.val *= 1 - self.alpha
                self.val += self.alpha * self.loss_man.soft_bit_entropy.detach()
                
            self.pbar.child.comment += f' avg_bpp: {self.val / 2 :.4f} imp-mean-var {(torch.mean(self.importance_map),torch.var(self.importance_map))}'
            msg = f"bitcost_loss={self.loss_man.bit_cost_loss_value:.1f} "
            msg += f"l2reg_loss={self.loss_man.l2_reg_loss:.1f} "
            msg += f"autoencoder_loss_value={ self.loss_man.autoencoder_loss_value:.1f} "
            msg += f"si_loss={self.loss_man.si_net_loss_value} "
            msg += f"feat_loss_value={self.loss_man.feat_loss_value:.1f}"

            self.pbar.child.comment += msg

# %%
class BitEntropy(Callback):
    "Wrap a `func` in a callback for metrics computation."
    def __init__(self,loss_man,alpha=0.1, logger=logger):
        # If it's a partial, use func.func
        #         name = getattr(func,'func',func).__name__
        self.loss_man = loss_man
        self.alpha = alpha
        self.logger = logger
        
    def on_epoch_begin(self, **kwargs):
        "Set the inner value to 0."
        self.val = 0.0
        self.iter = 0
        
        self.val_si_loss = None
        
    def on_batch_end(self, last_output, last_target, **kwargs):
        "Update metric computation with `last_output` and `last_target`."
      
        self.val *= 1 - self.alpha
        self.val += self.alpha * self.loss_man.soft_bit_entropy.detach()
        if self.val_si_loss is None:
            self.val_si_loss = self.loss_man.si_net_loss_value
        else :
            self.val_si_loss *= 1 - self.alpha
            self.val_si_loss += self.alpha * self.loss_man.si_net_loss_value.detach()
            
        if self.iter % 500 == 0 :
            importance_map  = last_output[3].detach()
            msg = f"iter {self.iter}: bpp = {self.val / 2:.3f}, impmap- mean {torch.mean(importance_map):.4f} var {torch.var(importance_map):.4f} "
            msg += f" total loss{self.loss_man.total_loss:.1f}  l2reg_loss={self.loss_man.l2_reg_loss:.1f}"
            msg += f"autoencoder_loss_value={ self.loss_man.autoencoder_loss_value:.1f}"
            msg += f"si_loss={self.val_si_loss:.1f}"
            msg += f"feat_loss_value={self.loss_man.feat_loss_value:.1f}"
            self.logger.info(msg)
            print(msg)
        self.iter += 1

    def on_epoch_end(self, last_metrics, **kwargs):
        "Set the final result in `last_metrics`."
        return add_metrics(last_metrics, self.val)

# %%
config.use_si_flag = SiNetChannelIn.WithSideInformation
config.use_si_flag
# Out:
# <SiNetChannelIn.WithSideInformation: 6>

# %%
torch.__version__
# Out:
# '1.5.1'

# %%
# x = nn.Sequential(nn.Conv2d(in_channels=2,out_channels=3 , kernel_size=1),nn.ReLU())

# %% [markdown]
# #  LOAD BASE-AE

# %%
baseline_autoencoder = BaseAutoEncoder()
path = "../src/dsin/data"
pct= 1 #0.0005 #0.25

valid_image_list = SideinformationImageImageList.from_csv(
    path=path, csv_names=["KITTI_stereo_val.txt"],pct=pct/10)
train_image_list = SideinformationImageImageList.from_csv(
    path=path, csv_names=["KITTI_stereo_train.txt"],pct=pct)

image_lists = ItemLists(
    path=path, train=train_image_list, valid=valid_image_list)


tfms =  get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1., max_lighting=None, max_warp=None, p_affine=0.0, p_lighting=0.0)

batchsize = 1

data = (image_lists
        .label_from_func(lambda x: x)
        .transform(None, size=(336, 336), resize_method=ResizeMethod.CROP, tfm_y=True)
        .databunch(bs=batchsize))

learn = Learner(data=data,
                     model=baseline_autoencoder,
                     opt_func=torch.optim.Adam,
                     loss_func=LossManager(SiNetChannelIn.NoSideInformation),
                     metrics=[AverageMetric(Distortions._calc_dist,"MS_SSIM")])
# learn.load('200815MAE-l2reg-baseline-1')
learn.load('200816MAE-l2reg-baseline-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.3908, 0.4180, 0.4425,  ..., 0.3650, 0.4149, 0.4032],
#          [0.3921, 0.4293, 0.4524,  ..., 0.3515, 0.4176, 0.4076],
#          [0.4221, 0.4440, 0.4560,  ..., 0.3500, 0.3250, 0.3604]]]), tensor([[[0.9016, 0.8349, 0.3893,  ..., 0.6715, 0.6809, 0.5699],
#          [0.6986, 0.6786, 0.3433,  ..., 0.7440, 0.7431, 0.5861],
#          [0.6458, 0.5601, 0.3251,  ..., 0.7049, 0.7001, 0.5220],
#          ...,
#          [0.2887, 0.2784, 0.2627,  ..., 0.1977, 0.2215, 0.2411],
#          [0.2654, 0.2611, 0.2539,  ..., 0.1826, 0.2218, 0.2430],
#          [0.2627, 0.2627, 0.2571,  ..., 0.2235, 0.2304, 0.2314]],
#
#         [[0.8942, 0.8625, 0.5363,  ..., 0.8588, 0.7903, 0.5942],
#          [0.9159, 0.8574, 0.5508,  ..., 0.9653, 0.8584, 0.6319],
#          [0.8661, 0.7704, 0.4945,  ..., 0.9178, 0.8089, 0.6004],
#          ...,
#          [0.3612, 0.3632, 0.3594,  ..., 0.2703, 0.2698, 0.2706],
#          [0.3539, 0.3524, 0.3426,  ..., 0.2567, 0.2844, 0.2776],
#          [0.3574, 0.3589, 0.3487,  ..., 0.2491, 0.2852, 0.2941]],
#
#         [[0.9876, 0.8943, 0.6736,  ..., 1.0000, 0.9452, 0.8170],
#          [0.9881, 0.9048, 0.6852,  ..., 1.0000, 0.9124, 0.7463],
#          [0.9207, 0.8595, 0.6495,  ..., 0.9967, 0.8869, 0.7335],
#          ...,
#          [0.4780, 0.4949, 0.4751,  ..., 0.3566, 0.3633, 0.3608],
#          [0.4761, 0.4858, 0.4714,  ..., 0.3263, 0.3388, 0.3674],
#          [0.4671, 0.4431, 0.4460,  ..., 0.3205, 0.3313, 0.3682]]])]
# y: ImageList
# Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336)
# Path: ../src/dsin/data;
#
# Valid: LabelList (790 items)
# x: SideinformationImageImageList
# ImageSiTuple [tensor([[[0.1058, 0.0813, 0.0916,  ..., 0.0726, 0.0745, 0.0745],
#          [0.1150, 0.0782, 0.0720,  ..., 0.0549, 0.0766, 0.0929],
#          [0.1025, 0.0842, 0.0864,  ..., 0.0637, 0.1488, 0.2089],
#          ...,
#          [0.5995, 0.6746, 0.6000,  ..., 0.9840, 0.9942, 0.9733],
#          [0.7205, 0.5887, 0.5815,  ..., 0.9860, 0.9896, 0.9633],
#          [0.7021, 0.5497, 0.5793,  ..., 0.9893, 0.9922, 0.9689]],
#
#         [[0.0907, 0.0922, 0.0835,  ..., 0.0913, 0.0873, 0.0824],
#          [0.1079, 0.0864, 0.0775,  ..., 0.0819, 0.0907, 0.0877],
#          [0.1064, 0.0807, 0.0837,  ..., 0.0912, 0.1447, 0.1176],
#          ...,
#          [0.6219, 0.6658, 0.6355,  ..., 0.9797, 0.9910, 0.9999],
#          [0.6732, 0.6988, 0.6454,  ..., 0.9665, 0.9747, 0.9895],
#          [0.6214, 0.5625, 0.5753,  ..., 0.9765, 0.9799, 0.9726]],
#
#         [[0.0941, 0.0951, 0.0924,  ..., 0.0814, 0.0926, 0.0786],
#          [0.0854, 0.0889, 0.0884,  ..., 0.0812, 0.0845, 0.0867],
#          [0.0783, 0.0792, 0.0825,  ..., 0.0812, 0.0817, 0.0955],
#          ...,
#          [0.6765, 0.6800, 0.6564,  ..., 0.9968, 0.9997, 1.0000],
#          [0.7439, 0.7040, 0.6482,  ..., 1.0000, 1.0000, 1.0000],
#          [0.6827, 0.5754, 0.5018,  ..., 0.9962, 0.9760, 0.9842]]]), tensor([[[0.1157, 0.1039, 0.1112,  ..., 0.1911, 0.1677, 0.1182],
#          [0.1234, 0.0986, 0.1034,  ..., 0.1961, 0.1575, 0.1007],
#          [0.1060, 0.0946, 0.1040,  ..., 0.0857, 0.0660, 0.0869],
#          ...,
#          [0.6511, 0.6453, 0.6622,  ..., 0.9508, 0.9452, 0.9319],
#          [0.6622, 0.6654, 0.6726,  ..., 0.9949, 0.9831, 0.9446],
#          [0.6672, 0.6715, 0.6759,  ..., 0.9685, 0.9099, 0.9524]],
#
#         [[0.1191, 0.1039, 0.1140,  ..., 0.2416, 0.2823, 0.1505],
#          [0.1122, 0.1029, 0.1099,  ..., 0.2528, 0.1445, 0.0644],
#          [0.1123, 0.1036, 0.1084,  ..., 0.1277, 0.0683, 0.0750],
#          ...,
#          [0.6595, 0.6547, 0.6574,  ..., 0.9675, 0.9757, 0.9818],
#          [0.6458, 0.6513, 0.6598,  ..., 0.9610, 0.9709, 0.9984],
#          [0.6530, 0.6714, 0.6891,  ..., 0.9990, 1.0000, 1.0000]],
#
#         [[0.1137, 0.1137, 0.1151,  ..., 0.1954, 0.1834, 0.1571],
#          [0.1089, 0.1093, 0.1104,  ..., 0.1255, 0.1080, 0.0748],
#          [0.1006, 0.1038, 0.1027,  ..., 0.1079, 0.0964, 0.0774],
#          ...,
#          [0.6978, 0.6639, 0.6887,  ..., 0.9903, 0.9921, 0.9999],
#          [0.7199, 0.6675, 0.6833,  ..., 1.0000, 1.0000, 1.0000],
#          [0.6466, 0.6725, 0.6953,  ..., 0.9981, 1.0000, 1.0000]]])],ImageSiTuple [tensor([[[0.0730, 0.0362, 0.0392,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0621, 0.0387, 0.0464,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0559, 0.0511, 0.0630,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [1.0000, 1.0000, 1.0000,  ..., 0.5792, 0.5591, 0.5236],
#          [1.0000, 1.0000, 1.0000,  ..., 0.5707, 0.5558, 0.5818],
#          [0.9338, 0.8993, 0.8568,  ..., 0.5625, 0.5529, 0.5801]],
#
#         [[0.0750, 0.0519, 0.0563,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0739, 0.0565, 0.0537,  ..., 1.0000, 1.0000, 1.0000],
#          [0.0579, 0.0553, 0.0539,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [1.0000, 1.0000, 1.0000,  ..., 0.5746, 0.5172, 0.5423],
#          [0.9991, 0.9922, 0.9610,  ..., 0.5002, 0.4951, 0.5416],
#          [0.9075, 0.7237, 0.6862,  ..., 0.5081, 0.5245, 0.5526]],
#
#         [[0.0691, 0.0560, 0.0485,  ..., 1.0000, 1.0000, 1.0000],
#          [0.

#          [1.0000, 1.0000, 1.0000,  ..., 0.2122, 0.2146, 0.2773],
#          [1.0000, 1.0000, 1.0000,  ..., 0.2247, 0.2081, 0.3813],
#          ...,
#          [0.1321, 0.1445, 0.1623,  ..., 0.6669, 0.6565, 0.6415],
#          [0.1249, 0.1377, 0.2115,  ..., 0.6610, 0.6830, 0.6505],
#          [0.1363, 0.1397, 0.4085,  ..., 0.5401, 0.5030, 0.6028]]]), tensor([[[1.0000, 1.0000, 1.0000,  ..., 0.3807, 0.4709, 0.5638],
#          [1.0000, 1.0000, 1.0000,  ..., 0.3154, 0.3122, 0.5296],
#          [1.0000, 1.0000, 1.0000,  ..., 0.4081, 0.2025, 0.5260],
#          ...,
#          [0.2306, 0.2323, 0.2339,  ..., 0.7076, 0.6593, 0.6915],
#          [0.2240, 0.2211, 0.2213,  ..., 0.7191, 0.6848, 0.7189],
#          [0.2196, 0.2206, 0.2235,  ..., 0.9525, 0.6291, 0.6386]],
#
#         [[1.0000, 1.0000, 1.0000,  ..., 0.3018, 0.4493, 0.5869],
#          [1.0000, 1.0000, 1.0000,  ..., 0.2471, 0.2849, 0.5216],
#          [1.0000, 1.0000, 1.0000,  ..., 0.2594, 0.2534, 0.5155],
#          ...,
#          [0.2532, 0.2467, 0.2425,  ..., 0.6069, 0.5675, 0.6203],
#          [0.2431, 0.2313, 0.2303,  ..., 0.6712, 0.6228, 0.6733],
#          [0.2260, 0.2204, 0.2395,  ..., 0.6888, 0.6129, 0.6117]],
#
#         [[1.0000, 1.0000, 1.0000,  ..., 0.5263, 0.5511, 0.5063],
#          [1.0000, 1.0000, 1.0000,  ..., 0.2967, 0.3498, 0.4530],
#          [1.0000, 1.0000, 1.0000,  ..., 0.2670, 0.3349, 0.4343],
#          ...,
#          [0.3110, 0.3146, 0.3030,  ..., 0.6005, 0.5840, 0.5475],
#          [0.3039, 0.3129, 0.3001,  ..., 0.6236, 0.5819, 0.5013],
#          [0.3005, 0.3186, 0.3258,  ..., 0.6192, 0.5834, 0.4834]]])]
# y: ImageList
# Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336),Image (3, 336, 336)
# Path: ../src/dsin/data;
#
# Test: None, model=BaseAutoEncoder(
#   (enc): Encoder(
#     (pre_res_model): Sequential(
#       (0): ChangeImageStatsToKitti(
#         (sigmoid): Sigmoid()
#       )
#       (1): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): Conv2d(3, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): Conv2d(64, 128, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (res_model): Sequential(
#       (0): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (1): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (2): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (3): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (4): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (5): ResBlock(
#         (model): Sequential(
#           (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#         )
#       )
#     )
#     (post_sum_model): Conv2d(128, 33, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   )
#   (dec): Decoder(
#     (pre_uberblock_model): Conv2dReluBatch2d(
#       (model): Sequential(
#         (0): ConvTranspose2d(32, 128, kernel_size=[3, 3], stride=[2, 2], padding=[1, 1], output_padding=[1, 1])
#         (1): ReLU()
#         (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (pre_sum_model): Sequential(
#       (0): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (1): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (2): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (3): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (4): UberResBlock(
#         (model): Sequential(
#           (0): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (1): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#           (2): ResBlock(
#             (model): Sequential(
#               (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#               (1): ReLU()
#               (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#             )
#           )
#         )
#       )
#       (5): ResBlock(
#         (model): Sequential(
#           (0): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#           (1): ReLU()
#           (2): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (3): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#         )
#       )
#     )
#     (post_sum_model): Sequential(
#       (0): Conv2dReluBatch2d(
#         (model): Sequential(
#           (0): ConvTranspose2d(128, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#           (1): ReLU()
#           (2): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): ConvTranspose2d(64, 3, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#       (2): ChangeImageStatsToKitti(
#         (sigmoid): Sigmoid()
#       )
#     )
#   )
#   (importance_map_layer): ImportanceMapMult()
#   (quantizer): Quantizer(sigma=0.1)
#   (prob_classif): ProbClassifier(
#     (premodel): ConstantPad3d(padding=(4, 4, 4, 4, 4, 0, 0, 0), value=0)
#     (model): Sequential(
#       (0): MaskedConv3d(
#         (conv): Conv3d(1, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#       )
#       (1): ReLU()
#       (2): MaskedResblock(
#         (model): Sequential(
#           (0): MaskedConv3d(
#             (conv): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#           )
#           (1): ReLU()
#           (2): MaskedConv3d(
#             (conv): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#           )
#         )
#       )
#       (3): MaskedConv3d(
#         (conv): Conv3d(24, 6, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#       )
#       (4): ReLU()
#     )
#   )
#   (noramlize): ChangeImageStatsToKitti(
#     (sigmoid): Sigmoid()
#   )
#   (denoramlize): ChangeImageStatsToKitti(
#     (sigmoid): Sigmoid()
#   )
# ), opt_func=<class 'torch.optim.adam.Adam'>, loss_func=LossManager(
#   (bit_cost_loss): CrossEntropyLoss()
#   (si_net_loss): L1Loss()
#   (feat_loss): FeatureLoss(
#     (m_feat): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): ReLU(inplace=True)
#       (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): ReLU(inplace=True)
#       (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (16): ReLU(inplace=True)
#       (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): ReLU(inplace=True)
#       (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (26): ReLU(inplace=True)
#       (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (29): ReLU(inplace=True)
#       (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (32): ReLU(inplace=True)
#       (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (36): ReLU(inplace=True)
#       (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): ReLU(inplace=True)
#       (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (42): ReLU(inplace=True)
#       (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (noramlize): ChangeImageStatsToKitti(
#       (sigmoid): Sigmoid()
#     )
#   )
# ), metrics=[AverageMetric
# func: <function Distortions._calc_dist at 0x7f35713fdc20>
# name: MS_SSIM], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('../src/dsin/data'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Sigmoid()
#   (1): Conv2d(3, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (2): ReLU()
#   (3): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Conv2d(64, 128, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (5): ReLU()
#   (6): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (8): ReLU()
#   (9): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (11): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (12): ReLU()
#   (13): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (15): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (16): ReLU()
#   (17): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (19): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (20): ReLU()
#   (21): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (23): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (24): ReLU()
#   (25): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (27): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (28): ReLU()
#   (29): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (30): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (31): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (32): ReLU()
#   (33): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (35): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (36): ReLU()
#   (37): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (38): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (39): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (40): ReLU()
#   (41): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (42): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (43): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (44): ReLU()
#   (45): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (47): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (48): ReLU()
#   (49): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (50): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (51): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (52): ReLU()
#   (53): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (54): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (55): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (56): ReLU()
#   (57): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (59): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (60): ReLU()
#   (61): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (62): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (63): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (64): ReLU()
#   (65): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (66): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (67): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (68): ReLU()
#   (69): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (71): Conv2d(128, 33, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#   (72): ConvTranspose2d(32, 128, kernel_size=[3, 3], stride=[2, 2], padding=[1, 1], output_padding=[1, 1])
#   (73): ReLU()
#   (74): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (75): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (76): ReLU()
#   (77): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (78): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (79): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (80): ReLU()
#   (81): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (83): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (84): ReLU()
#   (85): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (86): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (87): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (88): ReLU()
#   (89): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (90): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (91): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (92): ReLU()
#   (93): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (94): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (95): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (96): ReLU()
#   (97): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (98): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (99): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (100): ReLU()
#   (101): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (102): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (103): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (104): ReLU()
#   (105): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (106): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (107): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (108): ReLU()
#   (109): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (111): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (112): ReLU()
#   (113): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (114): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (115): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (116): ReLU()
#   (117): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (118): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (119): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (120): ReLU()
#   (121): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (122): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (123): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (124): ReLU()
#   (125): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (126): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (127): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (128): ReLU()
#   (129): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (130): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (131): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (132): ReLU()
#   (133): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (134): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (135): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (136): ReLU()
#   (137): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (138): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#   (139): ConvTranspose2d(128, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#   (140): ReLU()
#   (141): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (142): ConvTranspose2d(64, 3, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#   (143): Sigmoid()
#   (144): ImportanceMapMult()
#   (145): Quantizer(sigma=0.1)
#   (146): ConstantPad3d(padding=(4, 4, 4, 4, 4, 0, 0, 0), value=0)
#   (147): Conv3d(1, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (148): ReLU()
#   (149): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (150): ReLU()
#   (151): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (152): Conv3d(24, 6, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#   (153): ReLU()
#   (154): Sigmoid()
#   (155): Sigmoid()
# )], add_time=True, silent=False)

# %%
learn.layer_groups
# Out:
# [Sequential(
#    (0): Sigmoid()
#    (1): Conv2d(3, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#    (2): ReLU()
#    (3): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (4): Conv2d(64, 128, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#    (5): ReLU()
#    (6): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (7): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (8): ReLU()
#    (9): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (10): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (11): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (12): ReLU()
#    (13): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (14): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (15): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (16): ReLU()
#    (17): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (18): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (19): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (20): ReLU()
#    (21): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (22): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (23): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (24): ReLU()
#    (25): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (26): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (27): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (28): ReLU()
#    (29): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (30): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (31): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (32): ReLU()
#    (33): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (34): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (35): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (36): ReLU()
#    (37): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (38): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (39): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (40): ReLU()
#    (41): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (42): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (43): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (44): ReLU()
#    (45): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (46): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (47): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (48): ReLU()
#    (49): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (50): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (51): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (52): ReLU()
#    (53): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (54): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (55): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (56): ReLU()
#    (57): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (58): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (59): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (60): ReLU()
#    (61): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (62): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (63): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (64): ReLU()
#    (65): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (66): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (67): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (68): ReLU()
#    (69): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (70): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (71): Conv2d(128, 33, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], padding_mode=replicate)
#    (72): ConvTranspose2d(32, 128, kernel_size=[3, 3], stride=[2, 2], padding=[1, 1], output_padding=[1, 1])
#    (73): ReLU()
#    (74): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (75): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (76): ReLU()
#    (77): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (78): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (79): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (80): ReLU()
#    (81): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (82): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (83): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (84): ReLU()
#    (85): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (86): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (87): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (88): ReLU()
#    (89): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (90): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (91): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (92): ReLU()
#    (93): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (94): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (95): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (96): ReLU()
#    (97): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (98): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (99): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (100): ReLU()
#    (101): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (102): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (103): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (104): ReLU()
#    (105): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (106): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (107): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (108): ReLU()
#    (109): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (110): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (111): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (112): ReLU()
#    (113): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (114): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (115): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (116): ReLU()
#    (117): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (118): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (119): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (120): ReLU()
#    (121): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (122): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (123): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (124): ReLU()
#    (125): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (126): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (127): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (128): ReLU()
#    (129): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (130): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (131): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (132): ReLU()
#    (133): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (134): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (135): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (136): ReLU()
#    (137): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (138): Conv2d(128, 128, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], padding_mode=replicate)
#    (139): ConvTranspose2d(128, 64, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#    (140): ReLU()
#    (141): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    (142): ConvTranspose2d(64, 3, kernel_size=[5, 5], stride=[2, 2], padding=[2, 2], output_padding=[1, 1])
#    (143): Sigmoid()
#    (144): ImportanceMapMult()
#    (145): Quantizer(sigma=0.1)
#    (146): ConstantPad3d(padding=(4, 4, 4, 4, 4, 0, 0, 0), value=0)
#    (147): Conv3d(1, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#    (148): ReLU()
#    (149): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#    (150): ReLU()
#    (151): Conv3d(24, 24, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#    (152): Conv3d(24, 6, kernel_size=(2, 3, 3), stride=(1, 1, 1))
#    (153): ReLU()
#    (154): Sigmoid()
#    (155): Sigmoid()
#  )]

# %% [markdown]
# ## Freeze Base AE before training first time with SI-AE

# %%
learn.freeze_to(-1)

# %% [markdown]
# # Create  SI-AE

# %%
si_autoencoder = SideInformationAutoEncoder(base_line_auto_enc = learn.model)
learn = Learner(data=data,
                     model=si_autoencoder,
                     opt_func=torch.optim.Adam,
                     loss_func=LossManager(SiNetChannelIn.WithSideInformation,use_feat_loss = True),
                     metrics=[AverageMetric(Distortions._calc_dist,"MS_SSIM")])

# %%
model_fname = '200816MAE-l2reg-res-si-featloss'
for i in range(1,5):
    if i != 1 :
        learn.load(f'{model_fname}-{i - 1}',with_opt=True)
    
    config.si_loss_weight_alpha = 0.7
    learn.model.true_tuple_loss_false_just_out = True
    learn.model.use_side_infomation = SiNetChannelIn.WithSideInformation
    learn.loss_func.use_side_infomation = SiNetChannelIn.WithSideInformation
    learn.fit(1, lr=0.0001,wd=0,callbacks=[ParameterRunningAverageMetricCallback(learn.loss_func),BitEntropy(loss_man=learn.loss_func)])
    learn.save(f'{model_fname}-{i}')
    # !aws s3 cp ~/tDSIN/src/dsin/data/models/{model_fname}-{i}.pth  s3://dsin-us/models/
    # !aws s3 cp ~/tDSIN/tutorials/out.log s3://dsin-us/models/{model_fname}-{i}.log
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>MS_SSIM</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>180.200775</td>
#       <td>188.400436</td>
#       <td>0.300120</td>
#       <td>08:27</td>
#     </tr>
#   </tbody>
# </table>
# iter 0: bpp = 0.030, impmap- mean 0.1381 var 0.1189  total loss139.4  l2reg_loss=32.8autoencoder_loss_value=14.8si_loss=71.2feat_loss_value=52.3
# iter 500: bpp = 0.354, impmap- mean 0.2102 var 0.1660  total loss274.8  l2reg_loss=32.9autoencoder_loss_value=25.8si_loss=43.6feat_loss_value=28.0
# iter 1000: bpp = 0.331, impmap- mean 0.1809 var 0.1482  total loss200.0  l2reg_loss=33.1autoencoder_loss_value=19.5si_loss=32.8feat_loss_value=37.5
# iter 1500: bpp = 0.323, impmap- mean 0.1780 var 0.1463  total loss197.9  l2reg_loss=33.1autoencoder_loss_value=22.9si_loss=33.4feat_loss_value=35.7
# iter 2000: bpp = 0.339, impmap- mean 0.1549 var 0.1309  total loss118.1  l2reg_loss=33.2autoencoder_loss_value=20.4si_loss=38.3feat_loss_value=31.7
# upload: ../src/dsin/data/models/200816MAE-l2reg-res-si-featloss-1.pth to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-1.pth
# upload: ./out.log to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-1.log
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>MS_SSIM</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>212.997559</td>
#       <td>174.482559</td>
#       <td>0.149507</td>
#       <td>08:27</td>
#     </tr>
#   </tbody>
# </table>
# iter 0: bpp = 0.038, impmap- mean 0.2037 var 0.1622  total loss255.6  l2reg_loss=33.2autoencoder_loss_value=25.4si_loss=33.5feat_loss_value=31.2
# iter 500: bpp = 0.358, impmap- mean 0.1474 var 0.1256  total loss102.1  l2reg_loss=33.3autoencoder_loss_value=18.1si_loss=27.9feat_loss_value=24.3
# iter 1000: bpp = 0.364, impmap- mean 0.1857 var 0.1512  total loss200.4  l2reg_loss=33.5autoencoder_loss_value=23.3si_loss=24.6feat_loss_value=29.8
# iter 1500: bpp = 0.367, impmap- mean 0.1826 var 0.1492  total loss205.1  l2reg_loss=33.5autoencoder_loss_value=40.6si_loss=28.9feat_loss_value=28.5
# iter 2000: bpp = 0.330, impmap- mean 0.1579 var 0.1330  total loss121.3  l2reg_loss=33.5autoencoder_loss_value=17.5si_loss=27.0feat_loss_value=28.1
# upload: ../src/dsin/data/models/200816MAE-l2reg-res-si-featloss-2.pth to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-2.pth
# upload: ./out.log to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-2.log
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>MS_SSIM</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>233.173737</td>
#       <td>287.747742</td>
#       <td>0.142441</td>
#       <td>08:28</td>
#     </tr>
#   </tbody>
# </table>
# iter 0: bpp = 0.035, impmap- mean 0.1790 var 0.1470  total loss175.6  l2reg_loss=33.5autoencoder_loss_value=19.9si_loss=23.0feat_loss_value=27.7
# iter 500: bpp = 0.349, impmap- mean 0.1708 var 0.1416  total loss151.4  l2reg_loss=33.7autoencoder_loss_value=20.0si_loss=26.4feat_loss_value=25.5
# iter 1000: bpp = 0.346, impmap- mean 0.1819 var 0.1488  total loss178.3  l2reg_loss=33.9autoencoder_loss_value=23.6si_loss=22.9feat_loss_value=27.4
# iter 1500: bpp = 0.360, impmap- mean 0.2025 var 0.1615  total loss228.4  l2reg_loss=34.0autoencoder_loss_value=20.6si_loss=22.9feat_loss_value=26.2
# iter 2000: bpp = 0.392, impmap- mean 0.1880 var 0.1527  total loss185.5  l2reg_loss=34.0autoencoder_loss_value=15.4si_loss=24.0feat_loss_value=28.8
# upload: ../src/dsin/data/models/200816MAE-l2reg-res-si-featloss-3.pth to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-3.pth
# upload: ./out.log to s3://dsin-us/models/200816MAE-l2reg-res-si-featloss-3.log
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>MS_SSIM</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='37' class='' max='1576', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.35% [37/1576 00:09<06:49 265.8333 avg_bpp: 0.3900 imp-mean-var (tensor(0.2218, device='cuda:0'), tensor(0.1726, device='cuda:0'))bitcost_loss=186.7 l2reg_loss=34.0 autoencoder_loss_value=20.8 si_loss=20.954378128051758 feat_loss_value=22.1]
#     </div>
# iter 0: bpp = 0.040, impmap- mean 0.2276 var 0.1758  total loss266.8  l2reg_loss=34.0autoencoder_loss_value=13.7si_loss=12.1feat_loss_value=19.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a8ea4beec72d> in <module>
#       8     learn.model.use_side_infomation = SiNetChannelIn.WithSideInformation
#       9     learn.loss_func.use_side_infomation = SiNetChannelIn.WithSideInformation
# ---> 10     learn.fit(1, lr=0.0001,wd=0,callbacks=[ParameterRunningAverageMetricCallback(learn.loss_func),BitEntropy(loss_man=learn.loss_func)])
#      11     learn.save(f'{model_fname}-{i}')
#      12     get_ipython().system('aws s3 cp ~/tDSIN/src/dsin/data/models/{model_fname}-{i}.pth  s3://dsin-us/models/')
#
# ~/anaconda3/envs/tfastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/tfastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/tfastai/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# ~/anaconda3/envs/tfastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/tDSIN/src/dsin/ae/si_autoenc.py in forward(self, x, y)
#      62             l2_weights = 0
#      63             for p in self.parameters():
# ---> 64                 l2_weights += (p ** 2).sum()
#      65             return (x_reconstructed,  # for total loss
#      66                 x_dec,  # for auto-encoder loss
#
# KeyboardInterrupt:

# %%
learn.model.my_tuple[5]

# %%
learn.data.train_ds[1][0].img

# %%
learn.data.train_ds[1][0].si_img

# %%
learn.loss_func.soft_bit_entropy

# %%
config.si_loss_weight_alpha

# %%
learn.loss_func.autoencoder_loss_value

# %%
mt = learn.model.my_tuple[-2].squeeze_().detach()
mx, mn =torch.max(mt), torch.min(mt)
diff = mx-mn
show_image(Image(mt),figsize=(10,10))
# # print(mn)

# %%
# # show_image(Image(learn.model.my_tuple[0][:,:50,:50]/255))
# # Image(learn.model.my_tuple[2].squeeze_().detach()/255.0)
mt = learn.model.my_tuple[2].squeeze_().detach()
mx, mn =torch.max(mt), torch.min(mt)
diff = mx-mn
show_image(Image(mt),figsize=(10,10))
# # print(mn)

# torch.min(learn.model.my_tuple[2].squeeze_().detach())

# %%
aaa = (mt - mn)/(diff)

flip_lr(Image(aaa.cpu()))

# %%
# learn.model.true_tuple_loss_false_just_out = False

# learn.show_results(figsize=(30,30))

# %%
learn.model.my_tuple[-2].data
